# %% [markdown]
# Import libs

# %%
import pandas as pd

# %% [markdown]
# import dataset "This also shows that a pandas series is a 1D Array"

# %%
students_grading_df =  pd.read_csv("Students_Grading_Dataset.csv")
students_IDs = students_grading_df["Age"]
students_IDs.tail(10)
# Out:
# 4990    24
# 4991    20
# 4992    18
# 4993    22
# 4994    19
# 4995    19
# 4996    19
# 4997    24
# 4998    23
# 4999    21
# Name: Age, dtype: int64

# %% [markdown]
# Does the same thing as above although it reads from a json file

# %%
students_grading_df =  pd.read_json("Students_Grading_Dataset.json")
students_IDs = students_grading_df["Age"]
students_IDs.tail(10)
# Out:
# 4990    24
# 4991    20
# 4992    18
# 4993    22
# 4994    19
# 4995    19
# 4996    19
# 4997    24
# 4998    23
# 4999    21
# Name: Age, dtype: int64

# %% [markdown]
# SUmmary Statistics

# %%
summary_stats = students_grading_df.describe()
summary_stats
# Out:
#                Age  Attendance (%)  Midterm_Score  Final_Score  \
# count  5000.000000     4484.000000    5000.000000  5000.000000
# mean     21.048400       75.431409      70.326844    69.640788
# std       1.989786       14.372446      17.213209    17.238744
# min      18.000000       50.010000      40.000000    40.000000
# 25%      19.000000       63.265000      55.457500    54.667500
# 50%      21.000000       75.725000      70.510000    69.735000
# 75%      23.000000       87.472500      84.970000    84.500000
# max      24.000000      100.000000      99.980000    99.980000
#
#        Assignments_Avg  Quizzes_Avg  Participation_Score  Projects_Score  \
# count      4483.000000  5000.000000          5000.000000     5000.000000
# mean         74.798673    74.910728             4.980024       74.924860
# std          14.411799    14.504281             2.890136       14.423415
# min          50.000000    50.030000             0.000000       50.010000
# ...

# %%
students_grading_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  5000 non-null   object
#  1   First_Name                  5000 non-null   object
#  2   Last_Name                   5000 non-null   object
#  3   Email                       5000 non-null   object
#  4   Gender                      5000 non-null   object
#  5   Age                         5000 non-null   int64
#  6   Department                  5000 non-null   object
#  7   Attendance (%)              4484 non-null   float64
#  8   Midterm_Score               5000 non-null   float64
#  9   Final_Score                 5000 non-null   float64
#  10  Assignments_Avg             4483 non-null   float64
#  11  Quizzes_Avg                 5000 non-null   float64
#  12  Participation_Score         5000 non-null   float64
# ...

# %%
cumsum_age = students_grading_df["Age"].cumsum()
cummean_age = students_grading_df["Age"].cummin()
cumsum_age
cummean_age.head(30)
# Out:
# 0     22
# 1     18
# 2     18
# 3     18
# 4     18
# 5     18
# 6     18
# 7     18
# 8     18
# 9     18
# 10    18
# 11    18
# 12    18
# 13    18
# 14    18
# 15    18
# 16    18
# 17    18
# 18    18
# 19    18
# 20    18
# 21    18
# 22    18
# 23    18
# 24    18
# 25    18
# 26    18
# 27    18
# 28    18
# 29    18
# Name: Age, dtype: int64

# %% [markdown]
# How to change the index of a data frame

# %%
students_grading_df.set_index("Student_ID", inplace = True)
students_grading_df
# Out:
#            First_Name Last_Name                       Email  Gender  Age  \
# Student_ID
# S1000            Omar  Williams     student0@university.com  Female   22
# S1001           Maria     Brown     student1@university.com    Male   18
# S1002           Ahmed     Jones     student2@university.com    Male   24
# S1003            Omar  Williams     student3@university.com  Female   24
# S1004            John     Smith     student4@university.com  Female   23
# ...               ...       ...                         ...     ...  ...
# S5995           Ahmed     Jones  student4995@university.com    Male   19
# S5996            Emma     Brown  student4996@university.com    Male   19
# S5997            John     Brown  student4997@university.com  Female   24
# S5998            Sara     Davis  student4998@university.com    Male   23
# S5999           Maria     Brown  student4999@university.com  Female   21
#
#              Department  Attendance (%)  Midterm_Score  Final_Score  \
# ...

# %% [markdown]
# changing the dtype of a column

# %%
students_grading_df["Age"] = students_grading_df["Age"].astype(int)
students_grading_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000 entries, S1000 to S5999
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   First_Name                  5000 non-null   object
#  1   Last_Name                   5000 non-null   object
#  2   Email                       5000 non-null   object
#  3   Gender                      5000 non-null   object
#  4   Age                         5000 non-null   int32
#  5   Department                  5000 non-null   object
#  6   Attendance (%)              4484 non-null   float64
#  7   Midterm_Score               5000 non-null   float64
#  8   Final_Score                 5000 non-null   float64
#  9   Assignments_Avg             4483 non-null   float64
#  10  Quizzes_Avg                 5000 non-null   float64
#  11  Participation_Score         5000 non-null   float64
#  12  Projects_Score              5000 non-null   float64
# ...

# %% [markdown]
# .map amd .appy methods

# %% [markdown]
# .map is used to apply a function to each element in a pandas series. Examp[le Below

# %%
students_grading_df["Gender"]= students_grading_df["Gender"].map({"Male":0, "Female":1})
students_grading_df
# Out:
#            First_Name Last_Name                       Email  Gender  Age  \
# Student_ID
# S1000            Omar  Williams     student0@university.com     NaN   22
# S1001           Maria     Brown     student1@university.com     NaN   18
# S1002           Ahmed     Jones     student2@university.com     NaN   24
# S1003            Omar  Williams     student3@university.com     NaN   24
# S1004            John     Smith     student4@university.com     NaN   23
# ...               ...       ...                         ...     ...  ...
# S5995           Ahmed     Jones  student4995@university.com     NaN   19
# S5996            Emma     Brown  student4996@university.com     NaN   19
# S5997            John     Brown  student4997@university.com     NaN   24
# S5998            Sara     Davis  student4998@university.com     NaN   23
# S5999           Maria     Brown  student4999@university.com     NaN   21
#
#              Department  Attendance (%)  Midterm_Score  Final_Score  \
# ...

# %%
Engineering_Students = students_grading_df[students_grading_df['Department'] == 'Engineering']
Engineering_Students
# Out:
#            First_Name Last_Name                       Email  Gender  Age  \
# Student_ID
# S1000            Omar  Williams     student0@university.com       1   22
# S1001           Maria     Brown     student1@university.com       0   18
# S1005            Liam     Brown     student5@university.com       0   21
# S1007           Ahmed     Smith     student7@university.com       0   19
# S1009            Sara     Smith     student9@university.com       1   22
# ...               ...       ...                         ...     ...  ...
# S5984            Liam   Johnson  student4984@university.com       1   20
# S5988            John     Smith  student4988@university.com       1   19
# S5989            Liam     Brown  student4989@university.com       0   23
# S5991            John  Williams  student4991@university.com       1   20
# S5999           Maria     Brown  student4999@university.com       1   21
#
#              Department  Attendance (%)  Midterm_Score  Final_Score  \
# ...

# %%
students_grading_df['Department'].value_counts()
# Out:
# Department
# CS             2022
# Engineering    1469
# Business       1006
# Mathematics     503
# Name: count, dtype: int64

# %% [markdown]
# .apply is used to a function to apply a function to either axis ie a row or a column. APllied in complex operations

# %%
def calculate_totals(row):
    return row['Midterm_Score'] + row['FInal_Score'] + row['Assignments_Avg']

students_grading_df['Totale_Score'] =
